# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  5156990AC19CA285  electric_bike  2022-09-01 08:36:22  2022-09-01 08:39:05
# 1  E12D4A16BF51C274  electric_bike  2022-09-01 17:11:29  2022-09-01 17:14:45
# 2  A02B53CD7DB72DD7  electric_bike  2022-09-01 17:15:50  2022-09-01 17:16:12
# 3  C82E05FEE872DF11  electric_bike  2022-09-01 09:00:28  2022-09-01 09:10:32
# 4  4DEEB4550A266AE1  electric_bike  2022-09-01 07:30:11  2022-09-01 07:32:36
#
#   start_station_name start_station_id                end_station_name  \
# 0                NaN              NaN  California Ave & Milwaukee Ave
# 1                NaN              NaN                             NaN
# 2                NaN              NaN                             NaN
# 3                NaN              NaN                             NaN
# 4                NaN              NaN                             NaN
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
df.tail()
# Out:
#                  ride_id  rideable_type           started_at  \
# 426070  27E5A5C0B8FD0A3B  electric_bike  2022-09-16 20:14:23
# 426071  43643317E4B0C81F  electric_bike  2022-09-17 17:59:34
# 426072  25A3AC1383AEE522  electric_bike  2022-09-01 16:29:40
# 426073  AC77858075DAC2EC  electric_bike  2022-09-24 11:11:50
# 426074  470797B59BC932D1  electric_bike  2022-09-24 18:30:52
#
#                    ended_at             start_station_name start_station_id  \
# 426070  2022-09-16 20:24:55  Milwaukee Ave & Fullerton Ave              428
# 426071  2022-09-17 18:08:16             May St & Taylor St            13160
# 426072  2022-09-01 16:59:56  Milwaukee Ave & Fullerton Ave              428
# 426073  2022-09-24 11:21:56   Sheffield Ave & Kingsbury St            13154
# 426074  2022-09-24 19:01:55     Clarendon Ave & Junior Ter            13389
#
#        end_station_name end_station_id  start_lat  start_lng  end_lat  \
# ...

# %%
df=pd.read_csv("data")
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       5156990AC19CA285  electric_bike  2022-09-01 08:36:22
# 1       E12D4A16BF51C274  electric_bike  2022-09-01 17:11:29
# 2       A02B53CD7DB72DD7  electric_bike  2022-09-01 17:15:50
# 3       C82E05FEE872DF11  electric_bike  2022-09-01 09:00:28
# 4       4DEEB4550A266AE1  electric_bike  2022-09-01 07:30:11
# ...                  ...            ...                  ...
# 426070  27E5A5C0B8FD0A3B  electric_bike  2022-09-16 20:14:23
# 426071  43643317E4B0C81F  electric_bike  2022-09-17 17:59:34
# 426072  25A3AC1383AEE522  electric_bike  2022-09-01 16:29:40
# 426073  AC77858075DAC2EC  electric_bike  2022-09-24 11:11:50
# 426074  470797B59BC932D1  electric_bike  2022-09-24 18:30:52
#
#                    ended_at             start_station_name start_station_id  \
# 0       2022-09-01 08:39:05                            NaN              NaN
# 1       2022-09-01 17:14:45                            NaN              NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426075 entries, 0 to 426074
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             426075 non-null  object
#  1   rideable_type       426075 non-null  object
#  2   started_at          426075 non-null  object
#  3   ended_at            426075 non-null  object
#  4   start_station_name  386781 non-null  object
#  5   start_station_id    386781 non-null  object
#  6   end_station_name    360141 non-null  object
#  7   end_station_id      360141 non-null  object
#  8   start_lat           426075 non-null  float64
#  9   start_lng           426074 non-null  float64
#  10  end_lat             425764 non-null  float64
#  11  end_lng             425764 non-null  float64
#  12  member_casual       426074 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 42.3+ MB

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#            start_lat  start_lng   end_lat   end_lng
# start_lat   1.000000  -0.512254  0.889499 -0.454102
# start_lng  -0.512254   1.000000 -0.453186  0.780220
# end_lat     0.889499  -0.453186  1.000000 -0.500710
# end_lng    -0.454102   0.780220 -0.500710  1.000000

# %%
df.describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  426075.000000  426074.000000  425764.000000  425764.000000
# mean       41.903572     -87.647422      41.904211     -87.647821
# std         0.045557       0.027957       0.045865       0.028135
# min        41.648501     -87.840000      41.550000     -87.890000
# 25%        41.881032     -87.661427      41.881320     -87.661501
# 50%        41.900000     -87.644098      41.900960     -87.644336
# 75%        41.931279     -87.629634      41.931320     -87.629634
# max        42.070000     -87.528232      42.070000     -87.300000

# %%
df.nunique()
# Out:
# ride_id               426075
# rideable_type              3
# started_at            375591
# ended_at              376121
# start_station_name      1125
# start_station_id        1049
# end_station_name         844
# end_station_id           799
# start_lat             132218
# start_lng             129251
# end_lat                  774
# end_lng                  763
# member_casual              2
# dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'start_lat'}>,
#         <Axes: title={'center': 'start_lng'}>],
#        [<Axes: title={'center': 'end_lat'}>,
#         <Axes: title={'center': 'end_lng'}>]], dtype=object)

# %%
df.boxplot()
# Out:
# <Axes: >
